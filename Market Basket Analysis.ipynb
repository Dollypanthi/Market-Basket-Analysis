# %% [markdown]
# # Case Study

# %%
#Import the library 
import pandas as pd

# %%
grocery = pd.read_csv('groceries.csv',header = None)
grocery.head()
# Out:
#                  0                    1               2   \
# 0      citrus fruit  semi-finished bread       margarine
# 1    tropical fruit               yogurt          coffee
# 2        whole milk                  NaN             NaN
# 3         pip fruit               yogurt    cream cheese
# 4  other vegetables           whole milk  condensed milk
#
#                          3    4    5    6    7    8    9   ...   22   23   24  \
# 0               ready soups  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 1                       NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 2                       NaN  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 3              meat spreads  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
# 4  long life bakery product  NaN  NaN  NaN  NaN  NaN  NaN  ...  NaN  NaN  NaN
#
#     25   26   27   28   29   30   31
# 0  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...

# %%
print('The shape of the groceries dataframe is: ',grocery.shape)
# Out:
# The shape of the groceries dataframe is:  (9835, 32)

# %%
grocery.values[4,3]
# Out:
# 'long life bakery product'

# %%
#Creating a for Loop
transactions = []
for i  in range(0,len(grocery)):
    transactions.append([str(grocery.values[i,j]) for j in range(0, len(grocery.columns))])

# %%
transactions
# Out:
# [['citrus fruit',
#   'semi-finished bread',
#   'margarine',
#   'ready soups',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['tropical fruit',
#   'yogurt',
#   'coffee',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['whole milk',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
# ...

# %% [markdown]
# # Installing the apyori package

# %%
# !pip install apyori

# %% [markdown]
# * We will run the model only on items occruing more than twice in the transactions
#
#
# * To calculate minimum support = (3*7/ total transactions)

# %%
(21/len(grocery))
# Out:
# 0.002135231316725979

# %%
from apyori import apriori
rules = apriori(transactions, min_support = 0.00213, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length=2)

# %%
results = list(rules)
print(*results,sep='\n')
# Out:
# RelationRecord(items=frozenset({'hamburger meat', 'Instant food products'}), support=0.003050330452465684, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Instant food products'}), items_add=frozenset({'hamburger meat'}), confidence=0.379746835443038, lift=11.42143769597027)])
# RelationRecord(items=frozenset({'baking powder', 'whipped/sour cream'}), support=0.004575495678698526, ordered_statistics=[OrderedStatistic(items_base=frozenset({'baking powder'}), items_add=frozenset({'whipped/sour cream'}), confidence=0.25862068965517243, lift=3.607850330154072)])
# RelationRecord(items=frozenset({'root vegetables', 'beef'}), support=0.017386883579054397, ordered_statistics=[OrderedStatistic(items_base=frozenset({'beef'}), items_add=frozenset({'root vegetables'}), confidence=0.3313953488372093, lift=3.0403668431100312)])
# ...

# %% [markdown]
# # Converting the above output into a dataframe
#
# * To do this we need to create a user defined function

# %%
results[0][0]
# Out:
# frozenset({'Instant food products', 'hamburger meat'})

# %%
lhs = [tuple(i[2][0][0])[0] for i in results]

# %%
lhs
# Out:
# ['Instant food products',
#  'baking powder',
#  'beef',
#  'berries',
#  'liquor',
#  'red/blush wine',
#  'candles',
#  'condensed milk',
#  'flour',
#  'flour',
#  'flour',
#  'mustard',
#  'herbs',
#  'popcorn',
#  'processed cheese',
#  'rice',
#  'sliced cheese',
#  'turkey']

# %%
def conversion(results):
    lhs = [tuple(i[2][0][0])[0] for i in results]
    rhs = [tuple(i[2][0][1])[0] for i in results]
    support = [i[1] for i in results]
    confidence = [i[2][0][2] for i in results]
    lift = [i[2][0][3] for i in results]
    return list(zip(lhs,rhs,support,confidence,lift))
results_df = pd.DataFrame(conversion(results),columns=['LHS','RHS','Support','Confidence','Lift'])

# %%
results_df
# Out:
#                       LHS                 RHS   Support  Confidence       Lift
# 0   Instant food products      hamburger meat  0.003050    0.379747  11.421438
# 1           baking powder  whipped/sour cream  0.004575    0.258621   3.607850
# 2                    beef     root vegetables  0.017387    0.331395   3.040367
# 3                 berries  whipped/sour cream  0.009049    0.272171   3.796886
# 4                  liquor        bottled beer  0.004677    0.422018   5.240594
# 5          red/blush wine        bottled beer  0.004881    0.253968   3.153760
# 6                 candles           margarine  0.002135    0.238636   4.074633
# 7          condensed milk              coffee  0.002542    0.247525   4.263408
# 8                   flour           margarine  0.003762    0.216374   3.694516
# 9                   flour               sugar  0.004982    0.286550   8.463112
# 10                  flour  whipped/sour cream  0.004067    0.233918   3.263241
# ...

# %%
results_df.sort_values(by='Lift',ascending=False).head(10)
# Out:
#                       LHS                 RHS   Support  Confidence       Lift
# 0   Instant food products      hamburger meat  0.003050    0.379747  11.421438
# 9                   flour               sugar  0.004982    0.286550   8.463112
# 13                popcorn         salty snack  0.002237    0.309859   8.192110
# 14       processed cheese         white bread  0.004169    0.251534   5.975445
# 4                  liquor        bottled beer  0.004677    0.422018   5.240594
# 7          condensed milk              coffee  0.002542    0.247525   4.263408
# 6                 candles           margarine  0.002135    0.238636   4.074633
# 12                  herbs     root vegetables  0.007016    0.431250   3.956477
# 3                 berries  whipped/sour cream  0.009049    0.272171   3.796886
# 15                   rice     root vegetables  0.003152    0.413333   3.792102
